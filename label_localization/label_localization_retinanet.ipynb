# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/retinanet_label
# Out:
# /content/drive/MyDrive/retinanet_label

# %% [markdown]
# !pip install roboflow

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git
# Out:
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 6220, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 6220 (delta 5), reused 6 (delta 2), pack-reused 6205
# Receiving objects: 100% (6220/6220), 13.48 MiB | 12.29 MiB/s, done.
# Resolving deltas: 100% (4205/4205), done.

# %%
import pandas as pd
# %cd keras-retinanet/
# !pip install . --user
# !python setup.py build_ext --inplace
# Out:
# /content/drive/MyDrive/retinanet_label/keras-retinanet
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/retinanet_label/keras-retinanet
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for keras-retinanet: filename=keras_retinanet-1.0.0-cp37-cp37m-linux_x86_64.whl size=169568 sha256=b714ac4acf25f4a12490eb8947d0c107083e2b683b5a539d649b67d113bdd11c
#   Stored in directory: /root/.cache/pip/wheels/e4/c9/67/79465d2ac414dc48497d0aec51b9100987ba8ae499ef87860a
# Successfully built keras-retinanet
# ...
#   Attempting uninstall: keras-retinanet
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="yn8ZAu4O9J9XNYPT7SSL")
project = rf.workspace("myworkspace-am9qg").project("nutrition-labels-ya58q")
dataset = project.version(1).download("retinanet")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Nutrition-Labels-1 in retinanet:: 100%|██████████| 4714/4714 [00:28<00:00, 167.29it/s]

# %%
train_annotations = pd.read_csv('/content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/_annotations.csv', header=None)
train_annotations.to_csv('/content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/_annotations.csv', header=False, index=False)

# %%
valid_annotations = pd.read_csv('/content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/valid/_annotations.csv', header=None)
valid_annotations.to_csv('/content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/valid/_annotations.csv', header=False, index=False)

# %%
classes=pd.DataFrame([{'class':'ingredients','label':0}])
classes.to_csv("/content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/classes.csv",index=False,header=False)

# %%
# !chmod +x ./keras_retinanet/bin/train.py

# %%
# !keras_retinanet/bin/train.py --random-transform --batch-size 4 --steps 100 --epochs 50 csv /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/_annotations.csv /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/classes.csv --val-annotations /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/valid/_annotations.csv
# Out:
# ...
# 102945312/102945312 [==============================] - 4s 0us/step
# Creating model, this may take a second...
# 2022-10-17 13:35:42.354604: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "retinanet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1 (Conv2D)                 (None, None, None,   9408        ['input_1[0][0]']
#                                 64)
#
# ...

# %%
# !keras_retinanet/bin/train.py --weights /content/drive/MyDrive/retinanet_label/keras-retinanet/snapshots/v1/resnet50_csv_32.h5 --random-transform --batch-size 4 --steps 100 --epochs 50 csv /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/_annotations.csv /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/classes.csv --val-annotations /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/valid/_annotations.csv
# Out:
# Creating model, this may take a second...
# 2022-10-17 15:07:00.111838: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "retinanet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1 (Conv2D)                 (None, None, None,   9408        ['input_1[0][0]']
#                                 64)
#
#  bn_conv1 (BatchNormalization)  (None, None, None,   256         ['conv1[0][0]']
# ...

# %%
# !keras_retinanet/bin/train.py --weights /content/drive/MyDrive/retinanet_label/keras-retinanet/snapshots/v2/resnet50_csv_09.h5 --random-transform --batch-size 4 --steps 100 --epochs 50 csv /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/_annotations.csv /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/train/classes.csv --val-annotations /content/drive/MyDrive/retinanet_label/keras-retinanet/Nutrition-Labels-1/valid/_annotations.csv
# Out:
# Creating model, this may take a second...
# 2022-10-17 15:38:52.024167: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "retinanet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1 (Conv2D)                 (None, None, None,   9408        ['input_1[0][0]']
#                                 64)
#
#  bn_conv1 (BatchNormalization)  (None, None, None,   256         ['conv1[0][0]']
# ...
